# %%
import pandas as pd
df = pd.read_csv("All Files\ds1.csv")

# %%
pd.read_csv("All Files\ds1.csv", header=None)
# Out:
#          0            1           2               3          4       5   \
# 0    Emp ID  Name Prefix  First Name  Middle Initial  Last Name  Gender
# 1    677509         Drs.        Lois               H     Walker       F
# 2    940761          Ms.      Brenda               S   Robinson     NaN
# 3    428945          Dr.         Joe               W   Robinson       M
# 4    408351         Drs.       Diane               I      Evans       F
# ..      ...          ...         ...             ...        ...     ...
# 96   639892          Mr.        Jose               K       Hill       M
# 97   704709          Dr.      Harold               Z     Nelson       M
# 98   461593          Ms.      Nicole               O       Ward       F
# 99   392491         Mrs.     Theresa               R     Murphy       F
# 100  495141         Drs.       Tammy               B      Young       F
#
#                             6                 7                   8   \
# ...

# %%
df = pd.read_csv("All Files\ds1.csv",usecols=["Emp ID","First Name"]).head()
df
# Out:
#    Emp ID First Name
# 0  677509       Lois
# 1  940761     Brenda
# 2  428945        Joe
# 3  408351      Diane
# 4  193819   Benjamin

# %%
# pd.read_csv()
dfs = pd.read_csv("All Files\ds1.csv", chunksize=10)
for df in dfs:
    print(df)
# Out:
#    Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 0  677509        Drs.       Lois              H    Walker      F
# 1  940761         Ms.     Brenda              S  Robinson    NaN
# 2  428945         Dr.        Joe              W  Robinson      M
# 3  408351        Drs.      Diane              I     Evans      F
# 4  193819         Mr.   Benjamin              R   Russell      M
# 5  499687         Mr.    Patrick              F    Bailey      M
# 6  539712         Ms.      Nancy              T     Baker      F
# 7  380086        Mrs.      Carol              V    Murphy      F
# 8  477616        Hon.    Frances              B     Young      F
# 9  162402        Hon.      Diana              T  Peterson      F
#
#                          E Mail      Father's Name       Mother's Name  \
# 0       lois.walker@hotmail.com      Donald Walker        Helen Walker
# 1     brenda.robinson@gmail.com   Raymond Robinson       Judy Robinson
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
fig, ax=plt.subplots()
x=np.linspace(0,20,1000)
ax.plot(x,np.cos(x))
ax.axis('equal')
# text annotation to the plot where it indicate maxmimum value of the curve
ax.annotate('local maximum',xy=(6.28,1),xytext=(10,4),arrowprops=dict(facecolor='black',shrink=0.05))
# text annotation to the plot where it indicate minimum value of the curve
ax.annotate('local minimum',xy=(5 * np.pi,-1), xytext=(2,-6), arrowprops=dict(arrowstyle="->",connectionstyle="angle3,angleA=0,angleB=-90"));

# %%
import matplotlib.pyplot as plt
w = 4
h = 3
d = 70
plt.figure(figsize=(w,h),dpi=d)
plt.axis([0,5,0,5])
x=[0,3,5]
y=[1,4,3.5]
label_x = 1
label_y = 4 
arrow_x = 3
arrow_y = 4
arrow_properties=dict(facecolor="black",width=0.5,headwidth=4,shrink=0.1)
plt.annotate("maximum",xy=(arrow_x,arrow_y),xytext=(label_x,label_y),arrowprops=arrow_properties)
plt.plot(x,y)

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
df = pd.read_excel(r"house price.xlsx",sheet_name="Sheet2")
df
# Out:
#     area  bedroom  age   price
# 0   2600        3   15  550000
# 1   3000        2   14  565000
# 2   3200        5   11  610000
# 3   3600        4   19  680000
# 4   4000        5   10  745000
# 5   3800        6   19  710000
# 6   4500        6   15  800000
# 7   4200        5   10  780000
# 8   4100        3   18  790000
# 9   2800        2   12  570000
# 10  4800        2   14  820000
# 11  5000        3   17  848000
# 12  5120        4   19  876000
# 13  5300        3   19  904000
# 14  5600        2   17  932000
# 15  5800        5   19  960000

# %%
model.fit(df[['area','bedroom','age']],df.price)
# Out:
# LinearRegression()

# %%
model.predict([[3000,3,40]])
# Out:
# C:\Users\admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([606015.8766788])

# %%
model.coef_
# Out:
# array([ 130.64924131, 3906.75025786,  358.01861276])

# %%
model.intercept_
# Out:
# 188027.15746342298

# %%
df = pd.read_excel("bangalore house price prediction OHE-data.xlsx")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\CODE\5]_learning_AI\2]_Learning_Modules\Learning_Pandas.ipynb Cell 14 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/CODE/5%5D_learning_AI/2%5D_Learning_Modules/Learning_Pandas.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> df = pd.read_excel("bangalore house price prediction OHE-data.xlsx")
#       <a href='vscode-notebook-cell:/c%3A/CODE/5%5D_learning_AI/2%5D_Learning_Modules/Learning_Pandas.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> df
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
# ...

# %%
import pandas as pd
df = pd.DataFrame({
    'a': [1,2,3,4,5],
    'b': [6,7,8,9,10],
    'c': [11,12,13,14,15],
    'd': [16,17,18,19,20]
})
df = pd.DataFrame(
    [[4, 7, 10],
    [5, 8, 11],
    [6, 9, 12]],
    index=[1, 2, 3],
    columns=['a', 'b', 'c']
    )
df = pd.DataFrame(
{"a" : [4 ,5, 6],
"b" : [7, 8, 9],
"c" : [10, 11, 12]},
index = pd.MultiIndex.from_tuples(
[('d', 1), ('d', 2),
('e', 2)], names=['n', 'v']))
